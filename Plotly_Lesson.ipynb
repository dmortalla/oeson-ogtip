# %% [markdown]
# <a href="https://colab.research.google.com/github/dmortalla/oeson-ogtip/blob/main/Plotly_Lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly

# %%
import plotly.express as px
import pandas as pd

df = px.data.gapminder()
df.head()

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv')
df
# Out:
#                 country         pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923.0      Asia   43.828    974.580338
# 1               Albania   3600523.0    Europe   76.423   5937.029526
# 2               Algeria  33333216.0    Africa   72.301   6223.367465
# 3                Angola  12420476.0    Africa   42.731   4797.231267
# 4             Argentina  40301927.0  Americas   75.320  12779.379640
# ..                  ...         ...       ...      ...           ...
# 137             Vietnam  85262356.0      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332.0      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743.0      Asia   62.698   2280.769906
# 140              Zambia  11746035.0    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143.0    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
# prompt: Using dataframe df: year vs GDP per

# There is no year column in the dataframe.
# Please update the dataframe or specify which column to use for the x-axis.

# %%
# Filter data
df_us = df[df['country'] == 'United States']

# Create a line chart
fig = px.line(df_us, x='year', y='gdpPercap', title='GDP Per Capita by Year')

# Show the chart
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4a973fc132fc> in <cell line: 5>()
#       3
#       4 # Create a line chart
# ----> 5 fig = px.line(df_us, x='year', y='gdpPercap', title='Life Expectancy in the United StatesGDP Per Capita by Year')
#       6
#       7 # Show the chart
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
# ...
